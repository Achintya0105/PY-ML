# %%
import networkx as nx

# %%
G_symmetric = nx.Graph()

# %%
G_symmetric.add_edge('Amitabh Bachchan','Abhishek Bachchan')
G_symmetric.add_edge('Amitabh Bachchan','Aamir Khan')
G_symmetric.add_edge('Amitabh Bachchan','Akshay Kumar')
G_symmetric.add_edge('Amitabh Bachchan','Dev Anand')
G_symmetric.add_edge('Abhishek Bachchan','Aamir Khan')
G_symmetric.add_edge('Abhishek Bachchan','Akshay Kumar')
G_symmetric.add_edge('Abhishek Bachchan','Dev Anand')
G_symmetric.add_edge('Dev Anand','Amir Khan')

# %%
get_ipython().magic('matplotlib inline')

nx.draw_networkx(G_symmetric)

# %% [markdown]
# Assymetric Network

# %%
G_asymmetric = nx.DiGraph()
G_asymmetric.add_edge('A','B')
G_asymmetric.add_edge('A','D')
G_asymmetric.add_edge('C','A')
G_asymmetric.add_edge('D','E')

# %%
nx.spring_layout(G_asymmetric)
nx.draw_networkx(G_asymmetric)

# %%
nx.average_clustering(G_symmetric)
# Out:
# 0.5555555555555556

# %%
nx.shortest_path(G_asymmetric)
# Out:
# {'A': {'A': ['A'], 'B': ['A', 'B'], 'D': ['A', 'D'], 'E': ['A', 'D', 'E']},
#  'B': {'B': ['B']},
#  'D': {'D': ['D'], 'E': ['D', 'E']},
#  'C': {'C': ['C'],
#   'A': ['C', 'A'],
#   'B': ['C', 'A', 'B'],
#   'D': ['C', 'A', 'D'],
#   'E': ['C', 'A', 'D', 'E']},
#  'E': {'E': ['E']}}

# %%
import networkx as nx

G_fb = nx.read_edgelist(
    "C:/Users/achintya/Downloads/Compressed/datasetfb/facebook_combined.txt",
    create_using = nx.Graph(),
    nodetype = int
)

# %%
nx.draw_networkx(G_fb)

# %%
betCent = nx.betweenness_centrality(G_fb)

# %%
sorted(betCent,key=betCent.get,reverse=True)[:5]
# Out:
# [107, 1684, 3437, 1912, 1085]

# %%
import networkx as nx

G_fb1 = nx.read_edgelist(
    "C:/Users/achintya/Downloads/Compressed/datasetfb/friend_list_set1.txt",
    create_using = nx.Graph(),
    nodetype = str
)

# %%
nx.draw_networkx(G_fb1)

# %%
betCent = nx.betweenness_centrality(G_fb1)

# %%
sorted(betCent,key=betCent.get,reverse=True)[:5]
# Out:
# ['republic', 'majorgauravarya', 'deeptisachdeva_', 'princearihan', 'sachin_rt']

# %%
# !pip install -U textblob
# Out:
# Requirement already up-to-date: textblob in c:\programdata\anaconda3\lib\site-packages (0.15.3)
# ...

# %%
#Download NLTK

# !python -m textblob.download_corpora
# Out:
# Finished.
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\achintya\AppData\Roaming\nltk_data...
# ...

# %%
from textblob import TextBlob

# %%
blob = TextBlob("TextBlob is amazingly simple to use.A good activity!")
blob.sentiment.polarity
# Out:
# 0.4375

# %%
blob = TextBlob("I hate You")
blob.sentiment.polarity
# Out:
# -0.8

# %%
blob = TextBlob("That's Fucking Amazing")
blob.sentiment.polarity
# Out:
# 0.6000000000000001

# %%
blob = TextBlob("TextBlob is amazingly simple to use.What great Fun.I hate you")
for sentence in blob.sentences:
    print(sentence)
    print(sentence.sentiment.polarity)
    print("\n")
# Out:
# TextBlob is amazingly simple to use.What great Fun.I hate you
# 0.0

# %%
# !pip install bs4
# Out:
# ...
#   Stored in directory: C:\Users\achintya\AppData\Local\pip\Cache\wheels\a0\b0\b2\4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India"

# %%
#To make HTTP Requests
import requests

# %%
user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.132 Safari/537.36'

# %%
headers = {'User-Agent':user_agent}

# %%
#Get URL Content
page = requests.get(url,headers)

# %%
soup =  BeautifulSoup(page.content,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of state and union territory capitals in India - Wikipedia</title>
# ...

# %%
right_table = soup.find('table',class_ = 'wikitable sortable plainrowheaders')

# %%
print(right_table)
# Out:
# <table class="wikitable sortable plainrowheaders">
# <tbody><tr>
# <th scope="col">No.
# </th>
# <th scope="col">State or<br/>union territory
# </th>
# <th scope="col">Administrative capital
# </th>
# <th scope="col">Legislative capital
# </th>
# <th scope="col">Judicial capital
# </th>
# <th scope="col">Year of establishment
# </th>
# <th scope="col">Former capital
# </th></tr>
# <tr>
# <td>1
# </td>
# <th scope="row"><a href="/wiki/Andaman_and_Nicobar_Islands" title="Andaman and Nicobar Islands">Andaman and Nicobar Islands</a> <img alt="union territory" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
# </th>
# <td><a href="/wiki/Port_Blair" title="Port Blair">Port Blair</a>
# </td>
# <td> —
# </td>
# <td>Kolkata
# </td>
# <td>1955
# </td>
# <td>Calcutta (1945–1955)
# </td></tr>
# <tr>
# <td>2
# </td>
# ...

# %%
all_rows = right_table.findAll("tr")
all_rows[0]
# Out:
# <tr>
# <th scope="col">No.
# </th>
# <th scope="col">State or<br/>union territory
# </th>
# <th scope="col">Administrative capital
# </th>
# <th scope="col">Legislative capital
# </th>
# <th scope="col">Judicial capital
# </th>
# <th scope="col">Year of establishment
# </th>
# <th scope="col">Former capital
# </th></tr>

# %%
print(all_rows[0])
# Out:
# <tr>
# <th scope="col">No.
# </th>
# <th scope="col">State or<br/>union territory
# </th>
# <th scope="col">Administrative capital
# </th>
# <th scope="col">Legislative capital
# </th>
# <th scope="col">Judicial capital
# </th>
# <th scope="col">Year of establishment
# </th>
# <th scope="col">Former capital
# </th></tr>

# %%
A = []
B = []
C = []
D = []
E = []
F = []
G = []


for row in all_rows:
    all_tds = row.findAll('td')
    all_ths = row.findAll('th')
    
    if len(all_ths)> 0:
        B.append(all_ths[0].find(text=True).strip())
    if len(all_tds) > 0:
        A.append(all_tds[0].find(text=True).strip())
        C.append(all_tds[1].find(text=True).strip())
        D.append(all_tds[2].find(text=True).strip())
        E.append(all_tds[3].find(text=True).strip())
        F.append(all_tds[4].find(text=True).strip())
        G.append(all_tds[5].find(text=True).strip())
       

    
#print(A)    
print(B)
#print(C)
#print(D)
#print(E)
#print(F)
#print(G)
# Out:
# ['No.', 'Andaman and Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'National Capital Territory of Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']

# %%
del B[0]
print(B)
# Out:
# ['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh', 'Dadra and Nagar Haveli', 'Daman and Diu', 'National Capital Territory of Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal']

# %%
from lxml import html

# %%
import requests

# %%
amazon_url = 'https://www.amazon.com/product-reviews/B01DFKC2SO?pageNumber=2&sortBy=recent'

# %%
headers = {'User-Agent': user_agent}

# %%
page = requests.get(amazon_url,headers = headers)

# %%
page
# Out:
# <Response [200]>

# %%
page_content = html.fromstring(page.content)

# %%
page_content
# Out:
# <Element html at 0x5b3e663ea8>

# %%
xpath_reviews = '//div[@data-hook="review"]'
reviews = page_content.xpath(xpath_reviews)

# %%
print(reviews)
# Out:
# [<Element div at 0x5b43761818>, <Element div at 0x5b3e663f98>, <Element div at 0x5b43a0ae58>, <Element div at 0x5b43a0ab38>, <Element div at 0x5b43a0af98>, <Element div at 0x5b43a0af48>, <Element div at 0x5b43aa59f8>, <Element div at 0x5b43aa5a48>, <Element div at 0x5b43aa5048>, <Element div at 0x5b43aa5138>]

# %%
xpath_rating = './/i[@data-hook="review-star-rating"]//text()'
xpath_title = './/a[@data-hook="review-title"]//text()'
xpath_date = './/span[@data-hook="review-date"]//text()'
xpath_review = './/span[@data-hook="review-body"]//text()'

# %%
import pandas as pd
reviews_df = pd.DataFrame()
for review in reviews:
    rating = review.xpath(xpath_rating)
    title = review.xpath(xpath_title)
    date = review.xpath(xpath_date)
    review = review.xpath(xpath_review)
    reviews_df = reviews_df.append({
        'rating': rating,
        'title' : title,
        'date'  : date,
        'review': review
    },ignore_index= True)
print(reviews_df)
# Out:
#               date                rating           review  \
# 0  [July 11, 2019]  [5.0 out of 5 stars]  [July 11, 2019]
# 1  [July 11, 2019]  [5.0 out of 5 stars]  [July 11, 2019]
# 2  [July 11, 2019]  [5.0 out of 5 stars]  [July 11, 2019]
# 3  [July 11, 2019]  [5.0 out of 5 stars]  [July 11, 2019]
# 4  [July 11, 2019]  [5.0 out of 5 stars]  [July 11, 2019]
# 5  [July 10, 2019]  [5.0 out of 5 stars]  [July 10, 2019]
# 6  [July 10, 2019]  [5.0 out of 5 stars]  [July 10, 2019]
# 7  [July 10, 2019]  [2.0 out of 5 stars]  [July 10, 2019]
# 8  [July 10, 2019]  [5.0 out of 5 stars]  [July 10, 2019]
# 9  [July 10, 2019]  [5.0 out of 5 stars]  [July 10, 2019]
#
#                                                title
# 0          [best price, works, gift, \n            ]
# 1                          [Love It, \n            ]
# 2                        [excelente, \n            ]
# 3                             [Like, \n            ]
# 4                [works as expected, \n            ]
# ...

# %%
reviews_df.to_csv("amazon_reviews.csv",sep=',',encoding='utf-8')
